# %%
# ! pip3 install -U textblob --user

import pandas as pd
# from textblob import TextBlob

# %%
# read data from the sources
data= pd.read_json('/Users/apple/Desktop/10 academy/data/global_twitter_data.json',lines=True)

# %%
# view some raws
data.head()
# Out:
#                  created_at                   id               id_str  \
# 0 2022-08-07 22:31:20+00:00  1556407673284861952  1556407673284861952
# 1 2022-08-07 22:31:16+00:00  1556407654373027840  1556407654373027840
# 2 2022-08-07 22:31:07+00:00  1556407616208773122  1556407616208773120
# 3 2022-08-07 22:31:06+00:00  1556407614602461185  1556407614602461184
# 4 2022-08-07 22:31:04+00:00  1556407604238245889  1556407604238245888
#
#                                            full_text  truncated  \
# 0  RT @i_ameztoy: Extra random image (I):\n\nLets...      False
# 1  RT @IndoPac_Info: #China's media explains the ...      False
# 2  China even cut off communication, they don't a...      False
# 3  Putin to #XiJinping : I told you my friend, Ta...      False
# 4  RT @ChinaUncensored: I’m sorry, I thought Taiw...      False
#
#   display_text_range                                           entities  \
# 0           [0, 143]  {'hashtags': [{'text': 'City', 'indices': [132...
# ...

# %%
data.columns
# Out:
# Index(['created_at', 'id', 'id_str', 'full_text', 'truncated',
#        'display_text_range', 'entities', 'metadata', 'source',
#        'in_reply_to_status_id', 'in_reply_to_status_id_str',
#        'in_reply_to_user_id', 'in_reply_to_user_id_str',
#        'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place',
#        'contributors', 'retweeted_status', 'is_quote_status', 'retweet_count',
#        'favorite_count', 'favorited', 'retweeted', 'lang',
#        'possibly_sensitive', 'extended_entities', 'quoted_status_id',
#        'quoted_status_id_str', 'quoted_status', 'withheld_in_countries'],
#       dtype='object')

# %%
data['possibly_sensitive']
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#         ...
# 21995    0.0
# 21996    0.0
# 21997    NaN
# 21998    NaN
# 21999    NaN
# Name: possibly_sensitive, Length: 22000, dtype: float64

# %%
if 'possibly_sensitive' in tweet.keys(): 
    is_sensitive.append(tweet['possibly_sensitive'])
else: is_sensitive.append(None)

# %%
user= data['user']
user[0]['screen_name']
# Out:
# 'i_ameztoy'

# %%
data['entities']
# Out:
# 0        {'hashtags': [{'text': 'City', 'indices': [132...
# 1        {'hashtags': [{'text': 'China', 'indices': [18...
# 2        {'hashtags': [{'text': 'XiJinping', 'indices':...
# 3        {'hashtags': [{'text': 'XiJinping', 'indices':...
# 4        {'hashtags': [], 'symbols': [], 'user_mentions...
#                                ...
# 21995    {'hashtags': [{'text': 'China', 'indices': [40...
# 21996    {'hashtags': [{'text': 'China', 'indices': [40...
# 21997    {'hashtags': [{'text': 'Pelosi', 'indices': [1...
# 21998    {'hashtags': [{'text': 'Taiwan', 'indices': [1...
# 21999    {'hashtags': [{'text': 'Taiwan', 'indices': [1...
# Name: entities, Length: 22000, dtype: object

# %%
data['full_text'].head(3)
# Out:
# 0    RT @i_ameztoy: Extra random image (I):\n\nLets...
# 1    RT @IndoPac_Info: #China's media explains the ...
# 2    China even cut off communication, they don't a...
# Name: full_text, dtype: object

# %%
names=[]
for i,user in enumerate(data['user']):
    
    if i <5:
        print(user['name'])
# Out:
# Iban Ameztoy
# Earth Is Not Flat
# JJ
# JJ
# Dolores Vizzini

# %%
names=[]
for user in data['user']:
    names.append(user['name'])

names
# Out:
# ['Iban Ameztoy',
#  'Earth Is Not Flat',
#  'JJ',
#  'JJ',
#  'Dolores Vizzini',
#  'Gcrhaacne🇭🇰🇦🇺',
#  'Philipkuma',
#  'Norris G. Hohn π',
#  'Claudio Coloma',
#  'jmarzola',
#  '薛剑XueJian',
#  'wilsonchinonso',
#  'Earth Is Not Flat',
#  'Aurora',
#  'Rocky',
#  'Foxy_Jay',
#  '𝑭𝒐𝒓𝒕𝒖𝒏𝒆 𝑭𝒓𝒊𝒆𝒏𝒅𝒔𝒉𝒊𝒑 𝑺𝒒𝒖𝒂𝒅',
#  'Jinka',
#  'Covid19Travel',
#  'DOOS',
#  'DjPeaceOfMind',
#  'A far-easterner🇺🇦',
#  'arjlight',
#  'Kwame Seeker',
#  'A far-easterner🇺🇦',
#  'Jim 1999',
#  'Kathleen Larson',
#  'Robin Holdings',
#  'Jose Clavero',
#  'Mauricio',
#  'Marián Kišďurka',
#  '黄',
#  'JohnChan',
#  '梧村骨科',
#  'MartahJoy',
#  'stipe La',
#  'Norris G. Hohn π',
#  'xiaohuaSong',
#  'Ben #EndCovid',
#  'Hoggoth',
#  'robbi1',
#  'Market Trader',
#  'Sir Richard Tammadge',
#  'Héphaïstos',
#  'pat leahy',
#  'Odisseo',
#  'RenKeNews',
#  'Finance with Michael',
#  'Hoggoth',
#  'Ben #EndCovid',
#  'Marián Kišďurka',
#  'Vicki Gage',
#  'Atomtop',
#  '公法P',
#  'Philip Adams',
#  'Dantes',
# ...

# %%
data['user'][0]
# Out:
# {'id': 3418339671,
#  'id_str': '3418339671',
#  'name': 'Iban Ameztoy',
#  'screen_name': 'i_ameztoy',
#  'location': '',
#  'description': 'It´s not all about fancy words, but place always matters. Earth Observer 🛰🌍 Now @EU_scienceHub All Views My Own 🗺',
#  'url': None,
#  'entities': {'description': {'urls': []}},
#  'protected': False,
#  'followers_count': 20497,
#  'friends_count': 2621,
#  'listed_count': 232,
#  'created_at': 'Wed Aug 12 17:31:24 +0000 2015',
#  'favourites_count': 15760,
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': True,
#  'verified': False,
#  'statuses_count': 8097,
#  'lang': None,
#  'contributors_enabled': False,
#  'is_translator': False,
#  'is_translation_enabled': False,
#  'profile_background_color': '000000',
#  'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_tile': False,
# ...

# %%
data['is_quote_status'].value_counts()
# Out:
# False    20607
# True      1393
# Name: is_quote_status, dtype: int64

# %%
df1=data[data['in_reply_to_screen_name']!='NaN']

# %%
text = [ text for text in data['full_text']]
text[0]
# Out:
# 'RT @i_ameztoy: Extra random image (I):\n\nLets focus in one very specific zone of the western coast -&gt; Longjing District, Taichung #City, #Ta…'

# %%
'polarity' in data.columns
# Out:
# False

# %%
data_africa= pd.read_json('/Users/apple/Desktop/10 academy/data/africa_twitter_data.json',lines=True)

# %%
data_africa.head()
# Out:
#                  created_at                   id               id_str  \
# 0 2022-08-03 20:19:13+00:00  1554924874166149120  1554924874166149120
# 1 2022-08-02 15:24:42+00:00  1554488368347680771  1554488368347680768
# 2 2022-08-02 15:02:35+00:00  1554482802502127621  1554482802502127616
# 3 2022-08-01 13:51:42+00:00  1554102573635932160  1554102573635932160
# 4 2022-07-31 20:02:20+00:00  1553833459440910338  1553833459440910336
#
#                                            full_text  truncated  \
# 0  #Pelosi airplane landed safely in #Taiwan 🇹🇼  ...      False
# 1  Watch the video of the beginning of the Chines...      False
# 2  #Pelosi \n#Taipei \n#taiwan\n#XiJinping \n#Chi...      False
# 3  #HOBIPALOOZA #LaAcademiaExpulsion #WEURO2022 #...      False
# 4  #Pelosi\n#china\nChina Time ✌️ https://t.co/tE...      False
#
#   display_text_range                                           entities  \
# 0           [0, 222]  {'hashtags': [{'text': 'Pelosi', 'indices': [0...
# ...

# %%
data_africa['lang']
# Out:
# 0        en
# 1        en
# 2        en
# 3        en
# 4        en
#          ..
# 28603    en
# 28604    en
# 28605    en
# 28606    en
# 28607    en
# Name: lang, Length: 28608, dtype: object

# %%
df = data_africa[data_africa['lang']!='en']
df
# Out:
# Empty DataFrame
# Columns: [created_at, id, id_str, full_text, truncated, display_text_range, entities, metadata, source, in_reply_to_status_id, in_reply_to_status_id_str, in_reply_to_user_id, in_reply_to_user_id_str, in_reply_to_screen_name, user, geo, coordinates, place, contributors, is_quote_status, retweet_count, favorite_count, favorited, retweeted, lang, extended_entities, possibly_sensitive, quoted_status_id, quoted_status_id_str, quoted_status]
# Index: []
#
# [0 rows x 30 columns]
